# %% [markdown]
# ## First-time boring and/or painful setup
# - Click here to open in Colab:  [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alanturin-g/Computational_Neuroscience_UNITO/blob/main/PROVA.ipynb)
# - Be logged into a Google account (UniTO ok) to use the runtime and save in Drive.
#   - NB: this notebook is safe. In general.. be careful what you run.
# - <i>File → Save a copy in Drive</i> to create a personal editable copy.
#   - You can rename it if you want, and from now on can do <i>File → Save</i>
# - You will get A LOT of security prompts.. click "Trust", "Allow", "Run anyway", etc.
# - <i>Runtime → Change runtime type → T4 GPU</i>
# - Mount Drive running the code cell below. You'll need to grant *all* the requested permissions..
#   - It might go through the same auth loop twice-
#   - If all goes through, you'll get <i>Mounted at /content/drive</i> as output.

# %%
from google.colab import auth; auth.authenticate_user()
from google.colab import drive; drive.mount('/content/drive')

# %%
# Download an input file (if not already there). This one is just a test
import os, subprocess, shlex
DEST_PATH = "/content/drive/MyDrive/hello_world.txt"
if not os.path.exists(DEST_PATH):
    URL = "https://drive.google.com/uc?export=download&id=17mw-_ZitBR6hDDRmy8xE7vpiCZ28uDNT"
    cmd = f'wget -q -O {shlex.quote(DEST_PATH)} {shlex.quote(URL)}'
    ret = subprocess.call(cmd, shell=True)
    if ret != 0:
        raise RuntimeError("Download failed. Check sharing settings or FILE_ID.")
    else:
        print("Downloaded hello_world.txt!")
else:
    print("hello_world.txt already present:", DEST_PATH)

# %% [markdown]
# ## Regular use
# - The notebook now lives in your Gdrive folder, just open it from there
# - The downloaded files (like hello_world.txt in this case) are also there
# - You still need to (re-)run the cell below to remount

# %%
from google.colab import auth; auth.authenticate_user()
from google.colab import drive; drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Same cell as above, but you might need to remount
# ----> 2 from google.colab import auth; auth.authenticate_user()
#       3 from google.colab import drive; drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ## Finally, python stuff!
